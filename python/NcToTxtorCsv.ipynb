# %%
import xarray as xr

nc = xr.open_dataset('./montly.nc')
nc
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 73, latitude: 29, expver: 2, time: 387)
# Coordinates:
#   * longitude  (longitude) float32 19.0 19.25 19.5 19.75 ... 36.5 36.75 37.0
#   * latitude   (latitude) float32 38.0 37.75 37.5 37.25 ... 31.5 31.25 31.0
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1990-01-01 1990-02-01 ... 2022-03-01
# Data variables:
#     t2m        (time, expver, latitude, longitude) float32 ...
#     e          (time, expver, latitude, longitude) float32 ...
#     ro         (time, expver, latitude, longitude) float32 ...
#     sst        (time, expver, latitude, longitude) float32 ...
#     sf         (time, expver, latitude, longitude) float32 ...
#     tp         (time, expver, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-04-25 00:25:54 GMT by grib_to_netcdf-2.24.3: /opt/ecmw...

# %%
nc_RR = nc['tp']
nc_RR
# Out:
# <xarray.DataArray 'tp' (time: 387, expver: 2, latitude: 29, longitude: 73)>
# [1638558 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 19.0 19.25 19.5 19.75 ... 36.5 36.75 37.0
#   * latitude   (latitude) float32 38.0 37.75 37.5 37.25 ... 31.5 31.25 31.0
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1990-01-01 1990-02-01 ... 2022-03-01
# Attributes:
#     units:      m
#     long_name:  Total precipitation

# %%
nc_RR.to_dataframe().to_csv('precip.txt') #Txt dosyası olarak cikartir

# %%
nc_RR.to_dataframe().to_csv('precip.csv') #Csv dosyasi olarak cikartir
